# %% [markdown]
# # Lab 7: Self-Attention

# %% [markdown]
# This lab covers the following topics:
#
# - Gain insight into the self-attention operation using the sequential MNIST example from before.
# - Gain insight into positional encodings

# %% [markdown]
# ## 0 Initialization

# %% [markdown]
# Run the code cell below to download the MNIST digits dataset:

# %%
# !wget -O MNIST.tar.gz https://activeeon-public.s3.eu-west-2.amazonaws.com/datasets/MNIST.new.tar.gz
# !tar -zxvf MNIST.tar.gz

import torchvision
import torch
import torchvision.transforms as transforms
from torch import nn
import torch.nn.functional as F

from torch.utils.data import Subset

dataset = torchvision.datasets.MNIST('./', download=False, transform=transforms.Compose([transforms.ToTensor()]), train=True)
train_indices = torch.arange(0, 10000)
train_dataset = Subset(dataset, train_indices)

dataset=torchvision.datasets.MNIST('./', download=False, transform=transforms.Compose([transforms.ToTensor()]), train=False)
test_indices = torch.arange(0, 10000)
test_dataset = Subset(dataset, test_indices)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64,
                                          shuffle=True, num_workers=0)

test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=16,
                                          shuffle=False, num_workers=0)
# Out:
# --2024-03-07 02:10:20--  https://activeeon-public.s3.eu-west-2.amazonaws.com/datasets/MNIST.new.tar.gz
# Resolving activeeon-public.s3.eu-west-2.amazonaws.com (activeeon-public.s3.eu-west-2.amazonaws.com)... 52.95.150.162, 52.95.149.138, 52.95.144.14, ...
# Connecting to activeeon-public.s3.eu-west-2.amazonaws.com (activeeon-public.s3.eu-west-2.amazonaws.com)|52.95.150.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34812527 (33M) [application/x-gzip]
# Saving to: ‘MNIST.tar.gz’
#
# MNIST.tar.gz        100%[===================>]  33.20M  18.4MB/s    in 1.8s
#
# 2024-03-07 02:10:22 (18.4 MB/s) - ‘MNIST.tar.gz’ saved [34812527/34812527]
#
# MNIST/
# MNIST/raw/
# MNIST/raw/train-labels-idx1-ubyte.gz
# MNIST/raw/t10k-images-idx3-ubyte
# MNIST/raw/train-images-idx3-ubyte
# MNIST/raw/t10k-labels-idx1-ubyte.gz
# MNIST/raw/train-images-idx3-ubyte.gz
# MNIST/raw/t10k-images-idx3-ubyte.gz
# MNIST/raw/train-labels-idx1-ubyte
# MNIST/raw/t10k-labels-idx1-ubyte
# MNIST/processed/
# MNIST/processed/test.pt
# MNIST/processed/training.pt

# %% [markdown]
# ## Exercise 1: Self-Attention without Positional Encoding

# %% [markdown]
# In this section, will implement a very simple model based on self-attention without positional encoding. The model you will implement will consider the input image as a sequence of 28 rows. You may use PyTorch's [`nn.MultiheadAttention`](https://pytorch.org/docs/stable/generated/torch.nn.MultiheadAttention.html) for this part. Implement a model with the following architecture:
#
# * **Input**: Input image of shape `(batch_size, sequence_length, input_size)`, where $\text{sequence_length} = \text{image_height}$ and $\text{input_size} = \text{image_width}$.
#
# * **Linear 1**: Linear layer which converts input of shape `(sequence_length*batch_size, input_size)` to input of shape `(sequence_length*batch_size, embed_dim)`, where `embed_dim` is the embedding dimension.
#
# * **Attention 1**: `nn.MultiheadAttention` layer with 8 heads which takes an input of shape `(sequence_length, batch_size, embed_dim)` and outputs a tensor of shape `(sequence_length, batch_size, embed_dim)`.
#
# * **ReLU**: ReLU activation layer.
#
# * **Linear 2**: Linear layer which converts input of shape `(sequence_length*batch_size, embed_dim)` to input of shape `(sequence_length*batch_size, embed_dim)`.
#
# * **ReLU**: ReLU activation layer.
#
# * **Attention 2**: `nn.MultiheadAttention` layer with 8 heads which takes an input of shape `(sequence_length, batch_size, embed_dim)` and outputs a tensor of shape `(sequence_length, batch_size, embed_dim)`.
#
# * **ReLU**: ReLU activation layer.
#
# * **AvgPool**: Average along the sequence dimension from `(batch_size, sequence_length, embed_dim)` to `(batch_size, embed_dim)`
#
# * **Linear 3**: Linear layer which takes an input of shape `(batch_size, embed_dim)` and outputs the class logits of shape `(batch_size, 10)`.
#
#
# **NOTE**: Be cautious of correctly permuting and reshaping the input between layers. E.g. if `x` is of shape `(batch_size, sequence_length, input_size)`, note that `x.reshape(batch_size*sequence_length, -1) != x.permute(1,0,2).reshape(batch_size*sequence_length, -1)`. In this example, `x.reshape(batch_size*sequence_length, -1)` has `[batch0_seq0, batch0_seq1, ..., batch1_seq0, batch1_seq1, ...]` format, while `x.permute(1,0,2).reshape(batch_size*sequence_length, -1)` has `[batch0_seq0, batch1_seq0, ..., batch0_seq1, batch1_seq1, ...]` format.

# %%
# Self-attention without positional encoding
torch.manual_seed(691)

# Define your model here
class myModel(nn.Module):
    def __init__(self, input_size, embed_dim, seq_length,
                 num_classes=10, num_heads=8):
        super(myModel, self).__init__()
        # TODO: Initialize myModel
        self.linear1 = nn.Linear(input_size, embed_dim)
        self.attention1 = nn.MultiheadAttention(embed_dim, num_heads)
        self.relu = nn.ReLU()

        self.linear2 = nn.Linear(embed_dim, embed_dim)

        self.attention2 = nn.MultiheadAttention(embed_dim, num_heads)

        self.avgpool = nn.AvgPool1d(kernel_size=seq_length)
        self.linear3 = nn.Linear(embed_dim, num_classes)


    def forward(self,x):
        # TODO: Implement myModel forward pass
        batch_size, sequence_length, input_size = x.shape
        x = self.linear1(x)
        x = x.permute(1, 0, 2)
        x, _ = self.attention1(x, x, x)
        x = x.permute(1, 0, 2)
        x = self.relu(x)

        x = self.linear2(x)
        x = x.permute(1, 0, 2)
        x, _ = self.attention2(x, x, x)
        x = x.permute(1, 0, 2)
        x = self.relu(x)

        x = x.permute(0, 2, 1)
        x = self.avgpool(x)
        x = x.squeeze()
        x = self.linear3(x)

        return x

# %% [markdown]
# Train and evaluate your model by running the cell below. Expect to see  `60-80%` test accuracy.

# %%
# Same training code

import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms


# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters
sequence_length = 28
input_size = 28
hidden_size = 64
num_layers = 2
num_classes = 10
num_epochs = 8
learning_rate = 0.005

# Initialize model
model = myModel(input_size=input_size, embed_dim=hidden_size, seq_length=sequence_length)
model = model.to(device)
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Train the model
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()

        optimizer.step()

        if (i+1) % 10 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))


# Test the model
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Test Accuracy of the model on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Epoch [1/8], Step [10/157], Loss: 2.2235
# Epoch [1/8], Step [20/157], Loss: 2.0709
# Epoch [1/8], Step [30/157], Loss: 2.0252
# Epoch [1/8], Step [40/157], Loss: 1.9031
# Epoch [1/8], Step [50/157], Loss: 1.8192
# Epoch [1/8], Step [60/157], Loss: 1.5238
# Epoch [1/8], Step [70/157], Loss: 1.6520
# Epoch [1/8], Step [80/157], Loss: 1.6596
# Epoch [1/8], Step [90/157], Loss: 1.6377
# Epoch [1/8], Step [100/157], Loss: 1.6137
# Epoch [1/8], Step [110/157], Loss: 1.6625
# Epoch [1/8], Step [120/157], Loss: 1.6393
# Epoch [1/8], Step [130/157], Loss: 1.4784
# Epoch [1/8], Step [140/157], Loss: 1.3923
# Epoch [1/8], Step [150/157], Loss: 1.3929
# Epoch [2/8], Step [10/157], Loss: 1.0822
# Epoch [2/8], Step [20/157], Loss: 1.1429
# Epoch [2/8], Step [30/157], Loss: 1.1034
# Epoch [2/8], Step [40/157], Loss: 1.5262
# Epoch [2/8], Step [50/157], Loss: 1.1660
# Epoch [2/8], Step [60/157], Loss: 1.1410
# Epoch [2/8], Step [70/157], Loss: 1.1477
# Epoch [2/8], Step [80/157], Loss: 0.9627
# Epoch [2/8], Step [90/157], Loss: 0.9993
# Epoch [2/8], Step [100/157], Loss: 0.9694
# Epoch [2/8], Step [110/157], Loss: 0.7072
# Epoch [2/8], Step [120/157], Loss: 1.1875
# Epoch [2/8], Step [130/157], Loss: 0.9749
# Epoch [2/8], Step [140/157], Loss: 1.3111
# Epoch [2/8], Step [150/157], Loss: 1.0885
# Epoch [3/8], Step [10/157], Loss: 0.7460
# Epoch [3/8], Step [20/157], Loss: 1.0310
# Epoch [3/8], Step [30/157], Loss: 0.6417
# Epoch [3/8], Step [40/157], Loss: 0.6283
# Epoch [3/8], Step [50/157], Loss: 0.7940
# Epoch [3/8], Step [60/157], Loss: 0.8624
# Epoch [3/8], Step [70/157], Loss: 0.8786
# Epoch [3/8], Step [80/157], Loss: 0.7282
# Epoch [3/8], Step [90/157], Loss: 0.6449
# Epoch [3/8], Step [100/157], Loss: 0.5411
# Epoch [3/8], Step [110/157], Loss: 0.7538
# Epoch [3/8], Step [120/157], Loss: 0.7355
# Epoch [3/8], Step [130/157], Loss: 0.7896
# Epoch [3/8], Step [140/157], Loss: 0.8453
# Epoch [3/8], Step [150/157], Loss: 0.6451
# Epoch [4/8], Step [10/157], Loss: 0.9305
# Epoch [4/8], Step [20/157], Loss: 1.0334
# Epoch [4/8], Step [30/157], Loss: 0.5511
# Epoch [4/8], Step [40/157], Loss: 0.4913
# Epoch [4/8], Step [50/157], Loss: 0.9311
# Epoch [4/8], Step [60/157], Loss: 0.9870
# Epoch [4/8], Step [70/157], Loss: 0.5122
# Epoch [4/8], Step [80/157], Loss: 0.7474
# Epoch [4/8], Step [90/157], Loss: 0.8832
# Epoch [4/8], Step [100/157], Loss: 0.9310
# Epoch [4/8], Step [110/157], Loss: 1.0129
# Epoch [4/8], Step [120/157], Loss: 0.5444
# Epoch [4/8], Step [130/157], Loss: 0.4577
# Epoch [4/8], Step [140/157], Loss: 0.5265
# Epoch [4/8], Step [150/157], Loss: 0.6318
# Epoch [5/8], Step [10/157], Loss: 0.8797
# Epoch [5/8], Step [20/157], Loss: 0.8295
# Epoch [5/8], Step [30/157], Loss: 0.8394
# Epoch [5/8], Step [40/157], Loss: 0.6061
# Epoch [5/8], Step [50/157], Loss: 0.4906
# Epoch [5/8], Step [60/157], Loss: 0.6978
# Epoch [5/8], Step [70/157], Loss: 0.4378
# Epoch [5/8], Step [80/157], Loss: 0.5744
# Epoch [5/8], Step [90/157], Loss: 0.5775
# Epoch [5/8], Step [100/157], Loss: 0.4966
# Epoch [5/8], Step [110/157], Loss: 0.7072
# Epoch [5/8], Step [120/157], Loss: 0.6773
# Epoch [5/8], Step [130/157], Loss: 0.5939
# Epoch [5/8], Step [140/157], Loss: 0.6931
# Epoch [5/8], Step [150/157], Loss: 0.5189
# Epoch [6/8], Step [10/157], Loss: 0.4968
# Epoch [6/8], Step [20/157], Loss: 0.8060
# Epoch [6/8], Step [30/157], Loss: 0.3576
# Epoch [6/8], Step [40/157], Loss: 0.6514
# Epoch [6/8], Step [50/157], Loss: 0.9214
# Epoch [6/8], Step [60/157], Loss: 0.7610
# Epoch [6/8], Step [70/157], Loss: 0.5493
# Epoch [6/8], Step [80/157], Loss: 0.4512
# Epoch [6/8], Step [90/157], Loss: 0.5727
# Epoch [6/8], Step [100/157], Loss: 0.4893
# Epoch [6/8], Step [110/157], Loss: 0.5880
# Epoch [6/8], Step [120/157], Loss: 0.7312
# Epoch [6/8], Step [130/157], Loss: 0.4670
# Epoch [6/8], Step [140/157], Loss: 0.8258
# Epoch [6/8], Step [150/157], Loss: 0.5747
# Epoch [7/8], Step [10/157], Loss: 0.4796
# Epoch [7/8], Step [20/157], Loss: 0.6767
# Epoch [7/8], Step [30/157], Loss: 0.4962
# Epoch [7/8], Step [40/157], Loss: 0.6639
# Epoch [7/8], Step [50/157], Loss: 0.3349
# Epoch [7/8], Step [60/157], Loss: 0.7576
# Epoch [7/8], Step [70/157], Loss: 0.3462
# Epoch [7/8], Step [80/157], Loss: 0.8035
# Epoch [7/8], Step [90/157], Loss: 0.5499
# Epoch [7/8], Step [100/157], Loss: 0.4865
# Epoch [7/8], Step [110/157], Loss: 0.6121
# Epoch [7/8], Step [120/157], Loss: 0.4564
# Epoch [7/8], Step [130/157], Loss: 0.6102
# Epoch [7/8], Step [140/157], Loss: 0.4097
# Epoch [7/8], Step [150/157], Loss: 0.6462
# Epoch [8/8], Step [10/157], Loss: 0.4143
# Epoch [8/8], Step [20/157], Loss: 0.4183
# Epoch [8/8], Step [30/157], Loss: 0.4635
# Epoch [8/8], Step [40/157], Loss: 0.3513
# Epoch [8/8], Step [50/157], Loss: 0.6249
# Epoch [8/8], Step [60/157], Loss: 0.4568
# Epoch [8/8], Step [70/157], Loss: 0.6401
# Epoch [8/8], Step [80/157], Loss: 0.4324
# Epoch [8/8], Step [90/157], Loss: 0.5804
# Epoch [8/8], Step [100/157], Loss: 0.5989
# Epoch [8/8], Step [110/157], Loss: 0.5600
# Epoch [8/8], Step [120/157], Loss: 0.4826
# Epoch [8/8], Step [130/157], Loss: 0.4604
# Epoch [8/8], Step [140/157], Loss: 0.5092
# Epoch [8/8], Step [150/157], Loss: 0.3954
# Test Accuracy of the model on the 10000 test images: 82.07 %

# %% [markdown]
# ## Exercise 2: Self-Attention with Positional Encoding

# %% [markdown]
# Implement a similar model to exercise 1, except this time your embedded input should be added with the positional encoding. For the purpose of this lab, we will use a learned positional encoding, which will be a trainable embedding. Your positional encodings will be added to the initial transformation of the input.
#
# * **Input**: Input image of shape `(batch_size, sequence_length, input_size)`, where $\text{sequence_length} = \text{image_height}$ and $\text{input_size} = \text{image_width}$.
#
# * **Linear 1**: Linear layer which converts input of shape `(batch_size*sequence_length, input_size)` to input of shape `(batch_size*sequence_length, embed_dim)`, where `embed_dim` is the embedding dimension.
#
# * **Add Positional Encoding**: Add a learnable positional encoding of shape `(sequence_length, batch_size, embed_dim)` to input of shape `(sequence_length, batch_size, embed_dim)`, where `pos_embed` is the positional embedding size. The output will be of shape `(sequence_length, batch_size, embed_dim)`.
#
# * **Attention 1**: `nn.MultiheadAttention` layer with 8 heads which takes an input of shape `(sequence_length, batch_size, embed_dim)` and outputs a tensor of shape `(sequence_length, batch_size, embed_dim)`.
#
# * **ReLU**: ReLU activation layer.
#
# * **Linear 2**: Linear layer which converts input of shape `(sequence_length*batch_size, features_dim)` to input of shape `(sequence_length*batch_size, features_dim)`.
#
# * **ReLU**: ReLU activation layer.
#
# * **Attention 2**: `nn.MultiheadAttention` layer with 8 heads which takes an input of shape `(sequence_length, batch_size, features_dim)` and outputs a tensor of shape `(sequence_length, batch_size, features_dim)`.
#
# * **ReLU**: ReLU activation layer.
#
# * **AvgPool**: Average along the sequence dimension from `(batch_size, sequence_length, features_dim)` to `(batch_size, features_dim)`
#
# * **Linear 3**: Linear layer which takes an input of shape `(batch_size, sequence_length*features_dim)` and outputs the class logits of shape `(batch_size, 10)`.

# %%
# Self-attention with positional encoding
torch.manual_seed(691)

# Define your model here
class myModel(nn.Module):
    def __init__(self, input_size, embed_dim, seq_length,
                 num_classes=10, num_heads=8):
        super(myModel, self).__init__()
        # TODO: Initialize myModel
        self.positional_encoding = nn.Parameter(torch.rand(seq_length, embed_dim))
        self.linear1 = nn.Linear(input_size, embed_dim)
        self.attention1 = nn.MultiheadAttention(embed_dim, num_heads)
        self.relu = nn.ReLU()

        self.linear2 = nn.Linear(embed_dim, embed_dim)

        self.attention2 = nn.MultiheadAttention(embed_dim, num_heads)

        self.avgpool = nn.AvgPool1d(kernel_size = seq_length)
        self.linear3 = nn.Linear(embed_dim, num_classes)

    def forward(self,x):
        # TODO: Implement myModel forward pass
        batch_size, sequence_length, input_size = x.shape
        x = self.linear1(x)
        x = x + self.positional_encoding
        x = x.permute(1, 0, 2)
        x, _ = self.attention1(x, x, x)
        x = x.permute(1, 0, 2)
        x = self.relu(x)

        x = self.linear2(x)
        x = x.permute(1, 0, 2)
        x, _ = self.attention2(x, x, x)
        x = x.permute(1, 0, 2)
        x = self.relu(x)

        x = x.permute(0, 2, 1)
        x = self.avgpool(x)
        x = x.squeeze()
        x = self.linear3(x)
        return x

# %% [markdown]
# Use the same training code as the one from part 1 to train your model. You may copy the training loop here. Expect to see close to `~90+%` test accuracy.

# %%
# Same training code

import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms


# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters
sequence_length = 28
input_size = 28
hidden_size = 64
num_layers = 2
num_classes = 10
num_epochs = 8
learning_rate = 0.005

# Initialize model
model = myModel(input_size=input_size, embed_dim=hidden_size, seq_length=sequence_length)
model = model.to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Train the model
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()

        optimizer.step()

        if (i+1) % 10 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))


# Test the model
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Test Accuracy of the model on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Epoch [1/8], Step [10/157], Loss: 2.3532
# Epoch [1/8], Step [20/157], Loss: 2.2668
# Epoch [1/8], Step [30/157], Loss: 2.0704
# Epoch [1/8], Step [40/157], Loss: 1.9225
# Epoch [1/8], Step [50/157], Loss: 1.3949
# Epoch [1/8], Step [60/157], Loss: 1.5799
# Epoch [1/8], Step [70/157], Loss: 1.1907
# Epoch [1/8], Step [80/157], Loss: 0.7887
# Epoch [1/8], Step [90/157], Loss: 0.9927
# Epoch [1/8], Step [100/157], Loss: 0.8412
# Epoch [1/8], Step [110/157], Loss: 0.6720
# Epoch [1/8], Step [120/157], Loss: 0.9533
# Epoch [1/8], Step [130/157], Loss: 1.0182
# Epoch [1/8], Step [140/157], Loss: 0.5484
# Epoch [1/8], Step [150/157], Loss: 0.4473
# Epoch [2/8], Step [10/157], Loss: 0.3739
# Epoch [2/8], Step [20/157], Loss: 0.4157
# Epoch [2/8], Step [30/157], Loss: 0.3724
# Epoch [2/8], Step [40/157], Loss: 0.4486
# Epoch [2/8], Step [50/157], Loss: 0.3420
# Epoch [2/8], Step [60/157], Loss: 0.4034
# Epoch [2/8], Step [70/157], Loss: 0.2125
# Epoch [2/8], Step [80/157], Loss: 0.2978
# Epoch [2/8], Step [90/157], Loss: 0.2328
# Epoch [2/8], Step [100/157], Loss: 0.4080
# Epoch [2/8], Step [110/157], Loss: 0.5600
# Epoch [2/8], Step [120/157], Loss: 0.3932
# Epoch [2/8], Step [130/157], Loss: 0.3006
# Epoch [2/8], Step [140/157], Loss: 0.5527
# Epoch [2/8], Step [150/157], Loss: 0.4430
# Epoch [3/8], Step [10/157], Loss: 0.1358
# Epoch [3/8], Step [20/157], Loss: 0.1369
# Epoch [3/8], Step [30/157], Loss: 0.3063
# Epoch [3/8], Step [40/157], Loss: 0.3096
# Epoch [3/8], Step [50/157], Loss: 0.4074
# Epoch [3/8], Step [60/157], Loss: 0.1599
# Epoch [3/8], Step [70/157], Loss: 0.3442
# Epoch [3/8], Step [80/157], Loss: 0.2662
# Epoch [3/8], Step [90/157], Loss: 0.2212
# Epoch [3/8], Step [100/157], Loss: 0.0770
# Epoch [3/8], Step [110/157], Loss: 0.2857
# Epoch [3/8], Step [120/157], Loss: 0.2233
# Epoch [3/8], Step [130/157], Loss: 0.3704
# Epoch [3/8], Step [140/157], Loss: 0.2091
# Epoch [3/8], Step [150/157], Loss: 0.2339
# Epoch [4/8], Step [10/157], Loss: 0.1561
# Epoch [4/8], Step [20/157], Loss: 0.2046
# Epoch [4/8], Step [30/157], Loss: 0.0740
# Epoch [4/8], Step [40/157], Loss: 0.1464
# Epoch [4/8], Step [50/157], Loss: 0.2378
# Epoch [4/8], Step [60/157], Loss: 0.4060
# Epoch [4/8], Step [70/157], Loss: 0.3223
# Epoch [4/8], Step [80/157], Loss: 0.2589
# Epoch [4/8], Step [90/157], Loss: 0.3756
# Epoch [4/8], Step [100/157], Loss: 0.4750
# Epoch [4/8], Step [110/157], Loss: 0.3473
# Epoch [4/8], Step [120/157], Loss: 0.2227
# Epoch [4/8], Step [130/157], Loss: 0.0797
# Epoch [4/8], Step [140/157], Loss: 0.0976
# Epoch [4/8], Step [150/157], Loss: 0.1819
# Epoch [5/8], Step [10/157], Loss: 0.2501
# Epoch [5/8], Step [20/157], Loss: 0.1593
# Epoch [5/8], Step [30/157], Loss: 0.1406
# Epoch [5/8], Step [40/157], Loss: 0.0659
# Epoch [5/8], Step [50/157], Loss: 0.2529
# Epoch [5/8], Step [60/157], Loss: 0.0747
# Epoch [5/8], Step [70/157], Loss: 0.1111
# Epoch [5/8], Step [80/157], Loss: 0.1828
# Epoch [5/8], Step [90/157], Loss: 0.1014
# Epoch [5/8], Step [100/157], Loss: 0.2597
# Epoch [5/8], Step [110/157], Loss: 0.0821
# Epoch [5/8], Step [120/157], Loss: 0.2139
# Epoch [5/8], Step [130/157], Loss: 0.0433
# Epoch [5/8], Step [140/157], Loss: 0.1560
# Epoch [5/8], Step [150/157], Loss: 0.2950
# Epoch [6/8], Step [10/157], Loss: 0.1097
# Epoch [6/8], Step [20/157], Loss: 0.0984
# Epoch [6/8], Step [30/157], Loss: 0.1357
# Epoch [6/8], Step [40/157], Loss: 0.3897
# Epoch [6/8], Step [50/157], Loss: 0.0972
# Epoch [6/8], Step [60/157], Loss: 0.1347
# Epoch [6/8], Step [70/157], Loss: 0.1359
# Epoch [6/8], Step [80/157], Loss: 0.1785
# Epoch [6/8], Step [90/157], Loss: 0.1198
# Epoch [6/8], Step [100/157], Loss: 0.1624
# Epoch [6/8], Step [110/157], Loss: 0.2432
# Epoch [6/8], Step [120/157], Loss: 0.0667
# Epoch [6/8], Step [130/157], Loss: 0.2330
# Epoch [6/8], Step [140/157], Loss: 0.2289
# Epoch [6/8], Step [150/157], Loss: 0.0829
# Epoch [7/8], Step [10/157], Loss: 0.3200
# Epoch [7/8], Step [20/157], Loss: 0.2609
# Epoch [7/8], Step [30/157], Loss: 0.1168
# Epoch [7/8], Step [40/157], Loss: 0.2541
# Epoch [7/8], Step [50/157], Loss: 0.2194
# Epoch [7/8], Step [60/157], Loss: 0.1092
# Epoch [7/8], Step [70/157], Loss: 0.2283
# Epoch [7/8], Step [80/157], Loss: 0.1540
# Epoch [7/8], Step [90/157], Loss: 0.1034
# Epoch [7/8], Step [100/157], Loss: 0.2566
# Epoch [7/8], Step [110/157], Loss: 0.1896
# Epoch [7/8], Step [120/157], Loss: 0.1047
# Epoch [7/8], Step [130/157], Loss: 0.2597
# Epoch [7/8], Step [140/157], Loss: 0.1430
# Epoch [7/8], Step [150/157], Loss: 0.0954
# Epoch [8/8], Step [10/157], Loss: 0.2467
# Epoch [8/8], Step [20/157], Loss: 0.0478
# Epoch [8/8], Step [30/157], Loss: 0.1098
# Epoch [8/8], Step [40/157], Loss: 0.1341
# Epoch [8/8], Step [50/157], Loss: 0.2000
# Epoch [8/8], Step [60/157], Loss: 0.1345
# Epoch [8/8], Step [70/157], Loss: 0.1144
# Epoch [8/8], Step [80/157], Loss: 0.0826
# Epoch [8/8], Step [90/157], Loss: 0.2752
# Epoch [8/8], Step [100/157], Loss: 0.1857
# Epoch [8/8], Step [110/157], Loss: 0.1259
# Epoch [8/8], Step [120/157], Loss: 0.0679
# Epoch [8/8], Step [130/157], Loss: 0.0267
# Epoch [8/8], Step [140/157], Loss: 0.2052
# Epoch [8/8], Step [150/157], Loss: 0.1921
# Test Accuracy of the model on the 10000 test images: 92.69 %
